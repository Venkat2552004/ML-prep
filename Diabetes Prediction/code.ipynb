# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, MinMaxScaler
from sklearn.impute import KNNImputer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv("/content/drive/MyDrive/ML Lab/Data Sets/diabetes.csv")
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.shape
# Out:
# (768, 9)

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 763    False
# 764    False
# 765    False
# 766    False
# 767    False
# Length: 768, dtype: bool

# %%
data.isnull().values.any()
# Out:
# False

# %%
df = pd.DataFrame(data)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
#no need of one hat and label encoding here
#No null values or missing values, so no need of Imputing anything

# %%
X = df.iloc[:, :-1] #independent features
y = df.iloc[:, -1] #dependent feature

# %%
X
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
imputer = KNNImputer(n_neighbors = 5)
X_imputed = imputer.fit_transform(X)
X_imputed
# Out:
# array([[  6.   , 148.   ,  72.   , ...,  33.6  ,   0.627,  50.   ],
#        [  1.   ,  85.   ,  66.   , ...,  26.6  ,   0.351,  31.   ],
#        [  8.   , 183.   ,  64.   , ...,  23.3  ,   0.672,  32.   ],
#        ...,
#        [  5.   , 121.   ,  72.   , ...,  26.2  ,   0.245,  30.   ],
#        [  1.   , 126.   ,  60.   , ...,  30.1  ,   0.349,  47.   ],
#        [  1.   ,  93.   ,  70.   , ...,  30.4  ,   0.315,  23.   ]])

# %%
#train-test-split (7:3)
X_train, X_test, y_train, y_test = train_test_split(X_imputed, y, test_size = 0.3, random_state=52)

# %%
X_train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 754            8      154             78             32        0  32.4
# 558           11      103             68             40        0  46.2
# 584            8      124             76             24      600  28.7
# 78             0      131              0              0        0  43.2
# 193           11      135              0              0        0  52.3
# ..           ...      ...            ...            ...      ...   ...
# 503            7       94             64             25       79  33.3
# 86            13      106             72             54        0  36.6
# 151            4      114             65              0        0  21.9
# 525            3       87             60             18        0  21.8
# 668            6       98             58             33      190  34.0
#
#      DiabetesPedigreeFunction  Age
# 754                     0.443   45
# 558                     0.126   42
# ...

# %%
#Scaling data sets

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[ 2.44775583,  0.92681061,  0.03009315, ...,  1.25994233,
#          0.89751097,  0.38824266],
#        [-0.25007859,  1.14662771,  0.03009315, ...,  0.46941731,
#         -0.42031499,  0.1363462 ],
#        [ 0.64919955,  1.02101794,  0.23529977, ..., -0.30855969,
#          1.21868965,  0.47220815],
#        ...,
#        [ 0.04968079, -0.23507973, -0.22641513, ..., -1.23711288,
#         -0.12893639,  0.30427717],
#        [-0.25007859, -1.08294566, -0.4829234 , ..., -1.2496609 ,
#         -0.08920294, -1.03917066],
#        [ 0.64919955, -0.7375188 , -0.58552671, ...,  0.28119707,
#         -0.13555863,  0.80807011]])

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model.fit(X_train_scaled, y_train)

predictions = model.predict(X_test_scaled)

# %%
from sklearn.metrics import accuracy_score, classification_report

accuracy = accuracy_score(y_test, predictions)
report = classification_report(y_test, predictions)
print(f'Accuracy: {accuracy}')
print(f'Classification Report:\n{report}')
# Out:
# Accuracy: 0.7532467532467533
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.83      0.82       155
#            1       0.63      0.59      0.61        76
#
#     accuracy                           0.75       231
#    macro avg       0.72      0.71      0.72       231
# weighted avg       0.75      0.75      0.75       231

# %%
import joblib
joblib.dump(model,'diabetes_prediction.joblib')
# Out:
# ['diabetes_prediction.joblib']
